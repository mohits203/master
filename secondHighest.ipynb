# %%
num1 = int(input("Please enter first number"))
num2 = int(input("Please enter second number"))
num3 = int(input("Please enter third number"))
secondHighest = 0

if num1 > num2 and num1 > num3:
    if num2 > num3:
        secondHighest = num2
    else:
        secondHighest = num3

elif num2 > num1 and num2 > num3:
    if num1 > num3:
        secondHighest = num1
    else:
        secondHighest = num3

else:
    if num1 > num2:
        secondHighest = num1
    else:
        secondHighest = num2

print("The second highest number is:", secondHighest)
# Out:
# Please enter first number 20
# Please enter second number 15
# Please enter third number 30
# The second highest number is: 20
