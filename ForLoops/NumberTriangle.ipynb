# %% [markdown]
# Number Triangle
#
# Write a PHP program using nested loops to display:
#
# 1
#
# 22
#
# 333
#
# 4444

# %%
n = int(input("Please enter a number"))
for i in range(1,n+1):
    for j in range(1,i+1):
        print(i, end="")
    print()
# Out:
# Please enter a number 5
# 1
# 22
# 333
# 4444
# 55555
