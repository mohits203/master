# %%
firstList = ["Ram", "Mohan", "Betu", "Yashvi", "Damru", "Betu"]

for name in firstList:
    print(f"Name : {name}")
# Out:
# Name : Ram
# Name : Mohan
# Name : Betu
# Name : Yashvi
# Name : Damru
# Name : Betu

# %%
print(type(firstList))
# Out:
# <class 'list'>

# %%
firstList.append("Sonu")
firstList.append("Betu")
print(firstList)
# Out:
# ['Ram', 'Mohan', 'Betu', 'Yashvi', 'Damru', 'Betu', 'Sonu', 'Betu']

# %%
copyList = firstList.copy()

# %%
print(copyList)
# Out:
# ['Ram', 'Mohan', 'Betu', 'Yashvi', 'Damru', 'Betu', 'Sonu', 'Betu']

# %%
copyList.clear()

# %%
print(copyList)
# Out:
# []

# %%
secondList = ["Rohit", "Virat", "KL"]
firstList.extend(secondList)

# %%
print(firstList)
# Out:
# ['Ram', 'Mohan', 'Betu', 'Yashvi', 'Damru', 'Betu', 'Sonu', 'Betu', 'Rohit', 'Virat', 'KL']

# %%
print(firstList.index("Betu"))
print(firstList.index('Betu',6))
# Out:
# 2
# 7

# %%
firstList.insert(3, "Kailash")
print(firstList)
# Out:
# ['Ram', 'Mohan', 'Betu', 'Kailash', 'Yashvi', 'Damru', 'Betu', 'Sonu', 'Betu', 'Rohit', 'Virat', 'KL']

# %%
firstList.reverse()
print(firstList)
# Out:
# ['KL', 'Virat', 'Rohit', 'Betu', 'Sonu', 'Betu', 'Damru', 'Yashvi', 'Kailash', 'Betu', 'Mohan', 'Ram']

# %%
firstList.sort()
print(firstList)
# Out:
# ['Betu', 'Betu', 'Betu', 'Damru', 'KL', 'Kailash', 'Mohan', 'Ram', 'Rohit', 'Sonu', 'Virat', 'Yashvi']

# %%
firstList.remove("KL")
print(firstList)
# Out:
# ['Betu', 'Betu', 'Betu', 'Damru', 'Kailash', 'Mohan', 'Ram', 'Rohit', 'Sonu', 'Virat', 'Yashvi']

# %%
firstList.remove("Betu")
print(firstList)
# Out:
# ['Betu', 'Betu', 'Damru', 'Kailash', 'Mohan', 'Ram', 'Rohit', 'Sonu', 'Virat', 'Yashvi']

# %%
firstList.pop(3)
print(firstList)
# Out:
# ['Betu', 'Betu', 'Damru', 'Mohan', 'Ram', 'Rohit', 'Sonu', 'Virat', 'Yashvi']

# %%
print(len(firstList))
# Out:
# 9

# %%
firstList.count("Betu")
# Out:
# 2

# %%
max(firstList)
# Out:
# 'Yashvi'

# %%
sorted(firstList)
# Out:
# ['Betu', 'Betu', 'Damru', 'Mohan', 'Ram', 'Rohit', 'Sonu', 'Virat', 'Yashvi']

# %%
min(firstList)
# Out:
# 'Betu'
